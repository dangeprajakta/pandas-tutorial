# %%
import pandas as pd

# %%
data=[1,2,3,4]
df=pd.DataFrame(data)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
data=[['alex',10],['jhon',20],['dfgds',56],['ghdsgg',66]]

# %%
df=pd.DataFrame(data ,columns=['name','age'],dtype=float,index=['row1','row2','row3','row4'])

# %%
df
# Out:
#         name   age
# row1    alex  10.0
# row2    jhon  20.0
# row3   dfgds  56.0
# row4  ghdsgg  66.0

# %%
data1=[{11:'abc',22:'jdfhdj',66:'fdskjf'},{12:'pqr'},{13:'xyz'}]

# %%
df1=pd.DataFrame(data1)

# %%
df1
# Out:
#     11   12   13      22      66
# 0  abc  NaN  NaN  jdfhdj  fdskjf
# 1  NaN  pqr  NaN     NaN     NaN
# 2  NaN  NaN  xyz     NaN     NaN

# %%
d={'one':pd.Series([1,2,3,4],index=['a','b','c','d']),
    'two':pd.Series([5,6,7,8],index=['a','b','c','d']),
 }

# %%
d
# Out:
# {'one': a    1
#  b    2
#  c    3
#  d    4
#  dtype: int64, 'two': a    5
#  b    6
#  c    7
#  d    8
#  dtype: int64}

# %%
df2=pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-eae3d2c1cacb> in <module>
# ----> 1 df2=pd.DataFrame(d)
#
# NameError: name 'd' is not defined

# %%
df2
# Out:
#    one  two
# a    1    5
# b    2    6
# c    3    7
# d    4    8

# %% [markdown]
# # accessing the element

# %%
df2['one']
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: one, dtype: int64

# %% [markdown]
# # adding new column
# df2['three']=pd.Series([9,10,11,12],index=['a','b','c','d'])

# %%
df2
# Out:
#    one  two  three
# a    1    5      9
# b    2    6     10
# c    3    7     11
# d    4    8     12

# %%
df2['four']=pd.Series([55,66,77,33],index=['a','b','c','d'])

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2068723f1203> in <module>
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %% [markdown]
# # rows selection
# df2.loc['a']

# %%
df2.loc['c']
# Out:
# one       3
# two       7
# three    11
# four     77
# Name: c, dtype: int64

# %%
df2['one']
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: one, dtype: int64

# %%
df2.iloc[0:3]
# Out:
#    one  two  three  four
# a    1    5      9    55
# b    2    6     10    66
# c    3    7     11    77

# %%
df2[2:3]
# Out:
#    one  two  three  four
# c    3    7     11    77

# %%
#adding a row
lst1=[22,33,44,55]
f1=pd.DataFrame(lst1)

# %%
f1
# Out:
#     0
# 0  22
# 1  33
# 2  44
# 3  55

# %%
lst1=[4,5,6,7]
lst2=[5,6,7,8]
lst3=[8,9,0,1]
f1=pd.DataFrame(list(zip(lst1,lst2,lst3)))

# %%
f1
# Out:
#    0  1  2
# 0  4  5  8
# 1  5  6  9
# 2  6  7  0
# 3  7  8  1

# %% [markdown]
# # dataframe using list inside dic
# lst1=['abc','pqr','xyz']
# lst2=['id1','id2','id3']
# lst3=[54,78,90]
#
# dic1={'name':lst1,'id':lst2,'marks':lst3}
#
# df=pd.DataFrame(dic1)

# %%
df
# Out:
#   name   id  marks
# 0  abc  id1     54
# 1  pqr  id2     78
# 2  xyz  id3     90

# %%
dic={'name':'newname','id':'id4','marks':99}

# %%
dic
# Out:
# {'name': 'newname', 'id': 'id4', 'marks': 99}

# %%
df1=pd.DataFrame({"name":'ddffd',"id":'cjsd',"marks":88},index=[3])

# %%
df1
# Out:
#     name    id  marks
# 3  ddffd  cjsd     88

# %%
df.append(df1)
# Out:
#     name    id  marks
# 0    abc   id1     54
# 1    pqr   id2     78
# 2    xyz   id3     90
# 3  ddffd  cjsd     88
